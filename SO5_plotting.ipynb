# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
algo = ["DummyClassifier","SGDClassifier","LogisticRegression","MultinomialNB","PassiveAggressiveClassifier","Perceptron","LinearSVC","SVMrbf","SVMpoly","RandomForestClassifier","MLPClassifier"]
Acc = [6.889,35.7,40.973,28.913,37.443,31.218,43.256,36.27,36.5,34.5,36.2]
MacroF1 = [0.012,0.262,0.455,0.109,0.513,0.474,0.502,0.452,0.455,0.143,0.450]
MicroF1 = [0.032,0.393,0.528,0.273,0.544,0.503,0.568,0.508,0.528,0.358,0.508]
HamLoss = [0.024,0.0096,0.0087,0.0111,0.0101,0.0121,0.0084,0.00994,0.0099,0.00999,0.00994]

ax.bar(algo,Acc)
fig.autofmt_xdate() 
fig.suptitle('Accuracy Comparison of Various ML-Algorithms', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
algo = ["DummyClassifier","SGDClassifier","LogisticRegression","MultinomialNB","PassiveAggressiveClassifier","Perceptron","LinearSVC","SVMrbf","SVMpoly","RandomForestClassifier","MLPClassifier"]
Acc = [6.889,35.7,40.973,28.913,37.443,31.218,43.256,36.27,36.5,34.5,36.2]
MacroF1 = [0.012,0.262,0.455,0.109,0.513,0.474,0.502,0.452,0.455,0.143,0.450]
MicroF1 = [0.032,0.393,0.528,0.273,0.544,0.503,0.568,0.508,0.528,0.358,0.508]
HamLoss = [0.024,0.0096,0.0087,0.0111,0.0101,0.0121,0.0084,0.00994,0.0099,0.00999,0.00994]

ax.bar(algo,MacroF1)
fig.autofmt_xdate() 
fig.suptitle('MacroF1 Comparison of Various ML-Algorithms', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
algo = ["DummyClassifier","SGDClassifier","LogisticRegression","MultinomialNB","PassiveAggressiveClassifier","Perceptron","LinearSVC","SVMrbf","SVMpoly","RandomForestClassifier","MLPClassifier"]
Acc = [6.889,35.7,40.973,28.913,37.443,31.218,43.256,36.27,36.5,34.5,36.2]
MacroF1 = [0.012,0.262,0.455,0.109,0.513,0.474,0.502,0.452,0.455,0.143,0.450]
MicroF1 = [0.032,0.393,0.528,0.273,0.544,0.503,0.568,0.508,0.528,0.358,0.508]
HamLoss = [0.024,0.0096,0.0087,0.0111,0.0101,0.0121,0.0084,0.00994,0.0099,0.00999,0.00994]

ax.bar(algo,MicroF1)
fig.autofmt_xdate() 
fig.suptitle('MicroF1 Comparison of Various ML-Algorithms', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
algo = ["DummyClassifier","SGDClassifier","LogisticRegression","MultinomialNB","PassiveAggressiveClassifier","Perceptron","LinearSVC","SVMrbf","SVMpoly","RandomForestClassifier","MLPClassifier"]
Acc = [6.889,35.7,40.973,28.913,37.443,31.218,43.256,36.27,36.5,34.5,36.2]
MacroF1 = [0.012,0.262,0.455,0.109,0.513,0.474,0.502,0.452,0.455,0.143,0.450]
MicroF1 = [0.032,0.393,0.528,0.273,0.544,0.503,0.568,0.508,0.528,0.358,0.508]
HamLoss = [0.024,0.0096,0.0087,0.0111,0.0101,0.0121,0.0084,0.00994,0.0099,0.00999,0.00994]

ax.bar(algo,HamLoss)
fig.autofmt_xdate() 
fig.suptitle('Hamming Loss Comparison of Various ML-Algorithms', fontsize=16)
plt.show()

# %%
algo = ["DummyClassifier","SGDClassifier","LogisticRegression","MultinomialNB","PassiveAggressiveClassifier","Perceptron","LinearSVC","SVMrbf","SVMpoly","RandomForestClassifier","MLPClassifier"]
Acc = [6.889,35.7,40.973,28.913,37.443,31.218,43.256,36.27,36.5,34.5,36.2]
Acc = [(i - min(Acc))/max(Acc) for i in Acc]
Acc = [i * 100 for i in Acc]

MacroF1 = [0.012,0.262,0.455,0.109,0.513,0.474,0.502,0.452,0.455,0.143,0.450]
MacroF1 = [(i - min(MacroF1))/max(MacroF1) for i in MacroF1]
MacroF1 = [i * 100 for i in MacroF1]

MicroF1 = [0.032,0.393,0.528,0.273,0.544,0.503,0.568,0.508,0.528,0.358,0.508]
MicroF1 = [(i - min(MicroF1))/max(MicroF1) for i in MicroF1]
MicroF1 = [i * 100 for i in MicroF1]

HamLoss = [0.024,0.0096,0.0087,0.0111,0.0101,0.0121,0.0084,0.00994,0.0099,0.00999,0.00994]
HamLoss = [(i - min(HamLoss))/max(HamLoss) for i in HamLoss]
HamLoss = [i * 100 for i in HamLoss]

index = ["DummyClassifier","SGDClassifier","LogisticRegression","MultinomialNB","PassiveAggressiveClassifier","Perceptron","LinearSVC","SVMrbf","SVMpoly","RandomForestClassifier","MLPClassifier"]

df = pd.DataFrame({'Accuracy': Acc, 'Macro-F1': MacroF1,'Micro-F1': MicroF1,'Hamming Loss':HamLoss}, index=index)

fig = plt.figure()
ax = df.plot.bar(rot=0)
plt.xticks(rotation=90)
fig.autofmt_xdate()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = pd.Series(
    [6.889,35.7,40.973,28.913,37.443,31.218,43.256,36.27,36.5,34.5,36.2],
    index = ["DummyClassifier","SGDClassifier","LogisticRegression","MultinomialNB","PassiveAggressiveClassifier","Perceptron","LinearSVC","SVMrbf","SVMpoly","RandomForestClassifier","MLPClassifier"]
)

#Set descriptions:
plt.title("Total Delay Incident Caused by Carrier")
plt.ylabel('Delay Incident')
plt.xlabel('Carrier')

#Set tick colors:
ax = plt.gca()
ax.tick_params(axis='x', colors='blue')
ax.tick_params(axis='y', colors='red')

#Plot the data:
my_colors = list('rgbkymcrgb')  #red, green, blue, black, etc.

pd.Series.plot(s,'bar')
"""pd.Series.plot(
    s, 
    kind='bar', 
    color=my_colors,
)"""

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-7162bce42cd1> in <module>()
#      20 my_colors = list('rgbkymcrgb')  #red, green, blue, black, etc.
#      21
# ---> 22 pd.Series.plot(s,'bar')
#      23 """pd.Series.plot(
#      24     s,
#
# TypeError: __init__() takes 2 positional arguments but 3 were given
